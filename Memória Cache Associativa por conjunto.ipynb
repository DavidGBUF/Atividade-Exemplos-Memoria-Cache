# %% [markdown]
# # Slides memória Cache
# *Mapeamento Associativo por Conjuntos:

# %%
from IPython.display import Image
Image(filename='Exemplo 5.8.png')

# %% [markdown]
# Resolução:
#
# 1°Parte: bits de dados
#
# Sabemos que a memória cache guarda 32KB de dados e que cada Byte armazena 8 bits, então 32K x 8= 256K bits de dados.
#
# 2° Parte: Bits de tag
#
# Para saber a quantidade de bits de tag basta achar o tamanho da tag e multiplicar pelo número de linhas:
#
# número de linhas:
# 32KB(Capacidade da cache)/8B(largura linha)= 4K linhas
#
# número de conjuntos:
#
# 4K linhas/ 4 (Linhas por conjunto)= 1K de conjuntos
#
# número de blocos:
#
# 16MB (Capacidade MP)/ 8B (bytes por bloco)= 2M de blocos
#
# blocos por conjunto:
#
# 2M/ 1K = 2K (2¹¹) de blocos por linha, ou seja, 11 bits de tag para identificar o bloco dentro de um conjunto
#
# Total bit tags:
# 11 bits tags x 4K (numero de linhas)=44K bits de tag
#
# total bits da cache:
# 256K Bits de dados + 44 K bits de tag = 300 K bits para a cache.

# %% [markdown]
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

# %%
from IPython.display import Image
Image(filename='Exemplo 5.9.png')

# %% [markdown]
# A MP possui 64MB de capacidade e sabemos que (Devido ao livro assumir) cada célula possui 1 byte, então são 64M (2^26) de células/ endereços e serão necessários 26 bits para expressar esses endereços.
#
# Se cada bloco guarda 16 células (mesma largura da linha) serão necessários 4 bits reservados para escolher a célula dentro do bloco.
#
# A cache tem 32KB de capacidade e cada linha possui 16 B, então 32KB/16B= 2K linhas.
# cada bloco possui 4 linhas então 2K/4= 512 (2^9), ou seja, 9 bits serão reservados para identificar o conjunto do bloco.
#
# o endereço tem que somar 26 bits, nos quais 9 são de conjuntos e 4 são de célula dentro do bloco, então serão 13 bits de tag para identificar o bloco dentro de um conjunto, então será:
#
# 13 Bits de tag | 9 bits de conjunto | 4 bits de Célula = 26 bits (igual ao tamanho do endereço).

# %% [markdown]
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

# %%
from IPython.display import Image
Image(filename='Exemplo 5.10.png')

# %% [markdown]
# Resolução:
#
# O endereço contem 7 algarismos hexadecimais, nos quais cada um vale 4 bits, então 7 x 4 = 28 bits de endereço.
#
# A cache tem 64KB de capacidade e cada linha tem 32B, então 64KB/ 32B = 2K linhas
#
# Cada conjunto tem 4 linhas e são 2k linhas, então 2K(2¹¹) / 4 (2²) = 2^9 , ou seja 9 bits serão para identificar o conjunto.
#
# Convertendo o endereço para binário, temos:

# %%
hexa = bin(int("3FC92B6", 16))[2:].zfill(28)
hexa = ' '.join(hexa[i:i+4] for i in range(0, len(hexa), 4))
print(hexa)
# Out:
# 0011 1111 1100 1001 0010 1011 0110

# %% [markdown]
# Desses bits, os ultimos 5 serão para identificar a célula e os 9 bits que vem logo antes serão os bits de conjunto, então:
#
# 0011 1111 1100 10|01 0010 101|1 0110
#
# Bits tag-------------| Bits conjunto| bits célula.
#
# A resposta é: 01 0010 101
