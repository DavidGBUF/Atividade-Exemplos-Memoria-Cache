# %% [markdown]
# # Slides memória Cache
# *Mapeamento Associativo:

# %%
from IPython.display import Image
Image(filename='Exemplo 5.5.png')

# %% [markdown]
# Resolução:
#     A Quantidade total de total de bits que a memória cache pode trabalhar vai ser determinada
# por:
#     O n° de bits de dados que ela armazena + o n° de bits necessários para representar todos os
# blocos de dados que ela armazena.
#
# *O Primeiro pode ser facilmente obtido por:
# Se a memória tem capacidade de 32Kbytes e cada byte equivale a 8 bits então basta multiplicar:
# 32Kx8= 256K bits de dados
#
# *O segundo pode ser obtido por:
# Quantos bits de tag uma linha possui multiplicado pelo número de linhas.
# O número de linhas é dado por: Capacidade da cache/ n° de células por linha.
# 2^15/2³= 2¹² linhas, ou seja 12 bits para representar uma linha.
#
# A largura da linha vai ser igual a largura de um bloco, ou seja, 8 bytes (2³ células), então serão 3 bits paa escolher a célula do bloco.
#
# A MP possui 16MB de capacidade e sabemos que cada célula é um byte, e que cada bloco guarda 8 bytes, então sera 2M de blocos que na cache serão divididos entre 4K linhas, ou seja, 2X2^20(Total blocos)/2²X2^10(Total linhas)= 2^9 blocos/linha, ou seja, 9 bits de tag por linha.
#
# Se são 9 bits de tag por linha e há 4K linhas, então será 9X4K=36K bits de tag
#
# Então o total de bits da Cache vai ser :
#
# 256K+36K=292K de bits

# %% [markdown]
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

# %%
from IPython.display import Image
Image(filename='Exemplo 5.6.png')

# %% [markdown]
# Resolução:
#
#     Se o mapeamento é associativo direto, então cada bloco pode está em qualquer linha, ou seja, o endereço do bloco requisitado será comparado com cada bloco armazenado nas linhas da cache, comparado e passará adiante até encontrá-lo.
#
#     A largura da linha é igual a largura do bloco, ou seja, 16 (2^4) bytes, a MP possui 64MB e cada bloco possui 16B, então será 4M (ou 2²²) de blocos, sendo 22 bits para representar o bloco.
#
#     Então o formato do endereço da cache será: 22bits para bloco + 4 bits para selecionar a célula dentro do bloco.

# %% [markdown]
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

# %%
Image(filename='Exemplo 5.7.png')

# %% [markdown]
#     Se o bloco possui 32 Bytes de largura, então os últimos 5 bits de endereço serão para selecionar a célula do bloco armazenado e o restante serão os bits de campo do bloco selecionado, connvertendo o endereço de hexadecimal para binário temos:

# %%
hexa = bin(int("3FC92B6", 16))[2:].zfill(28)
hexa = ' '.join(hexa[i:i+4] for i in range(0, len(hexa), 4))
print(hexa)
# Out:
# 0011 1111 1100 1001 0010 1011 0110

# %% [markdown]
# ou seja, 0011 1111 1100 1001 0010 101 será o campo de bloco do endereço recebido
